# %%
import csv

f = open ('./Data/age.csv','r', encoding='cp949')
data=csv.reader(f)
header = next(data)

name=input("인구 구조가 알고 싶은 지역의 이름(읍면동 단위)을 입력해주세요: ")
home=[]

for row in data:
    if name in row[0]:
        for i in row[3:]:
            home.append(int(i.replace(',','')))
            
print(home)
# Out:
# 인구 구조가 알고 싶은 지역의 이름(읍면동 단위)을 입력해주세요: 상모사곡
# [203, 225, 282, 320, 311, 315, 357, 377, 337, 335, 315, 371, 335, 353, 333, 418, 403, 479, 537, 543, 464, 542, 505, 506, 478, 466, 398, 375, 349, 325, 342, 315, 390, 433, 427, 401, 526, 549, 566, 572, 517, 596, 543, 618, 648, 648, 676, 589, 712, 740, 771, 617, 553, 545, 523, 451, 459, 415, 397, 354, 265, 249, 211, 159, 163, 138, 148, 110, 95, 89, 109, 95, 69, 50, 56, 71, 85, 74, 53, 61, 59, 42, 37, 25, 25, 24, 23, 22, 10, 11, 13, 13, 6, 7, 2, 0, 3, 3, 1, 1, 2]

# %%
import csv

f = open ('./Data/age.csv','r', encoding='cp949')
data=csv.reader(f)
next(data)

name=input("인구 구조가 알고 싶은 지역의 이름(읍면동 단위)을 입력해주세요: ")
name2=input("비교하고 싶은 지역의 이름(읍면동 단위)을 입력해주세요: ")
home=[]
home2=[]

for row in data:
    if name in row[0]:
        for i in row[3:]:
            home.append(int(i.replace(',',''))/int(row[2].replace(',','')))
            
    if name2 in row[0]:
        for i in row[3:]:
            home2.append(int(i)/int(row[2].replace(',','')))
            
print(home)
print(home2)

plt.plot(home, label="name")
plt.plot(home2)
plt.legend()
plt.show()
# Out:
# 인구 구조가 알고 싶은 지역의 이름(읍면동 단위)을 입력해주세요: 상모사곡
# 비교하고 싶은 지역의 이름(읍면동 단위)을 입력해주세요: 임오
# ...

# %%
import numpy as np
import csv

f=open ('./Data/age.csv','r', encoding='cp949')
data = csv.reader(f)
next(data)

data= list(data)

name=input("인구 구조가 알고 싶은 지역의 이름(읍면동 단위)을 입력해주세요: ")

home=[]
away=[]

for row in data:
    if name in row[0]:
        home=np.array(row[3:], dtype=int)/int(row[2])

for row in data:
    away=np.array(row[3:], dtype=int)/int(row[2])
    print(np.sum(home - away))


import matplotlib.pyplot as plt

plt.plot(home)
plt.show()
# Out:
# 인구 구조가 알고 싶은 지역의 이름(읍면동 단위)을 입력해주세요: 상모사곡
# 1.5395670849294163e-17
# 2.1033522146218786e-17
# 1.0842021724855044e-17
# 1.691355389077387e-17
# 9.107298248878237e-18
# -5.421010862427522e-19
# 4.141652298894627e-17
# -1.5178830414797062e-18
# 1.7564075194265172e-17
# -2.0166160408230382e-17
# 8.673617379884035e-19
# 2.1467203015212988e-17
# 1.5178830414797062e-18
# 7.047314121155779e-18
# 6.505213034913027e-19
# 7.589415207398531e-18
# -4.336808689942018e-19
# 5.854691731421724e-18
# 1.214306433183765e-17
# 9.107298248878237e-18
# -1.951563910473908e-18
# -8.673617379884035e-19
# 7.37257477290143e-18
# 7.37257477290143e-18
# 1.1058862159352145e-17
# 6.938893903907228e-18
# 1.9949319973733282e-17
# -1.6263032587282567e-18
# -1.5178830414797062e-17
# -1.951563910473908e-18
# 7.914675859144182e-18
# 5.854691731421724e-18
# -2.3852447794681098e-18
# 2.688821387764051e-17
# -8.673617379884035e-19
# 1.0625181290357943e-17
# -8.890457814381136e-18
# -1.1492543028346347e-17
# ...

# %%
import numpy as np
import csv

f=open ('./Data/age.csv','r', encoding='cp949')
data = csv.reader(f)
next(data)

data= list(data)

name=input("인구 구조가 알고 싶은 지역의 이름(읍면동 단위)을 입력해주세요: ")

mn = 1
result_name=''
result = 0

for row in data:
    if name in row[0]:
        home=np.array(row[3:], dtype=int)/int(row[2])

for row in data:
    away=np.array(row[3:], dtype=int)/int(row[2])
    s= np.sum((home-away)**2)
    if s < mn and name not in row[0]:
        mn = s
        result_name=row[0]
        result = away
        
print(result_name)
print(result)

import matplotlib.pyplot as plt

plt.rc('font', family='AppleGothic')
plt.title(name + "지역과 가장 비슷한 인구 구조를 가진 지역")
plt.plot(home, label=name)
plt.plot(result, label=result_name)
plt.legend()
plt.show()
# Out:
# 인구 구조가 알고 싶은 지역의 이름(읍면동 단위)을 입력해주세요: 중계1동
# 서울특별시 강남구 대치1동(1168060000)
# [2.08554677e-03 2.99059536e-03 4.36784323e-03 4.48589305e-03
#  6.84688939e-03 8.18478731e-03 1.08212332e-02 1.31428796e-02
#  1.36544288e-02 1.54645260e-02 1.82977216e-02 2.21146657e-02
#  2.49872113e-02 2.25868650e-02 2.51446110e-02 2.44756621e-02
#  1.99897690e-02 2.05406682e-02 2.46330618e-02 1.85338213e-02
#  1.60941251e-02 1.44020777e-02 1.34576791e-02 1.08212332e-02
#  1.05851336e-02 8.65698658e-03 9.48333530e-03 7.86998780e-03
#  7.71258805e-03 6.41404006e-03 5.23354189e-03 5.43029158e-03
#  4.99744225e-03 4.01369378e-03 5.46964152e-03 6.68948963e-03
#  7.43713847e-03 1.00735844e-02 9.64073506e-03 1.29067800e-02
#  1.54645260e-02 1.68417739e-02 1.97143194e-02 2.38067131e-02
#  2.62857593e-02 2.64038091e-02 2.86861055e-02 3.20308504e-02
#  2.88435053e-02 2.90009050e-02 2.44756621e-02 1.96749695e-02
#  1.47955771e-02 1.62121749e-02 1.45201275e-02 1.28280801e-02
# ...
