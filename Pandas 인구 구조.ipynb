# %%
import pandas as pd

df= pd.read_csv('./Data/age.csv', encoding='cp949', index_col =0)
df = df.div(df['2019년02월_계_연령구간인구수'], axis=0)
del df['2019년02월_계_총인구수'], df['2019년02월_계_연령구간인구수']
df.head()

data= df.loc['경상북도 구미시 상모사곡동(4719064500)']

print(data)

import matplotlib.pyplot as plt

plt.plot(data)
plt.show()
# Out:
# 2019년02월_계_0세         0.006738
# 2019년02월_계_1세         0.007468
# 2019년02월_계_2세         0.009360
# 2019년02월_계_3세         0.010621
# 2019년02월_계_4세         0.010322
#                         ...
# 2019년02월_계_96세        0.000100
# 2019년02월_계_97세        0.000100
# 2019년02월_계_98세        0.000033
# 2019년02월_계_99세        0.000033
# 2019년02월_계_100세 이상    0.000066
# Name: 경상북도 구미시 상모사곡동(4719064500), Length: 101, dtype: float64
